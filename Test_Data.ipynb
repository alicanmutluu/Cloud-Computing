# %%
# !mkdir ~/kaggle3
# !echo '{"username":"minahanna","key":"26afea27d781596b15446a1d1a71cb21"}' >> ~/kaggle3/kaggle.json 
# !chmod 600 /home/ec2-user/kaggle3/kaggle.json

# %%
os.environ['KAGGLE_USERNAME'] = 'minahanna'
os.environ['KAGGLE_KEY'] = '26afea27d781596b15446a1d1a71cb21'

# %%
pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 1.2 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-dateutil in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from kaggle) (2.8.1)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from kaggle) (2.26.0)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from kaggle) (4.62.3)
# Collecting python-slugify
#   Downloading python_slugify-6.1.1-py2.py3-none-any.whl (9.1 kB)
# Requirement already satisfied: urllib3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from kaggle) (1.26.8)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 1.6 MB/s
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->kaggle) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->kaggle) (2.0.9)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73053 sha256=b69c669bfe266f7625762cb3d5f0f92f785b2c10f87e8ba8bf4e32957a1fcdd0
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/77/47/e4/44a4ba1b7dfd53faaa35f59f1175e123b213ff401a8a56876b
# Successfully built kaggle
# Installing collected packages: text-unidecode, python-slugify, kaggle
# Successfully installed kaggle-1.5.12 python-slugify-6.1.1 text-unidecode-1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !kaggle datasets download "mlg-ulb/creditcardfraud" -p"/home/ec2-user/kaggle3" --unzip
# Out:
# Downloading creditcardfraud.zip to /home/ec2-user/kaggle3
#  92%|███████████████████████████████████▏  | 61.0M/66.0M [00:00<00:00, 85.4MB/s]
# 100%|██████████████████████████████████████| 66.0M/66.0M [00:00<00:00, 91.4MB/s]

# %%
# Validate that Dataset is ready and retrievable 
import os
import pandas as pd

arr = os. listdir('/home/ec2-user/kaggle3')
print(arr)

dataset_path = '/home/ec2-user/kaggle3/creditcard.csv'

df = pd.read_csv(dataset_path)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 10)
df
# Out:
# ['creditcard.csv', 'kaggle.json']
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 0       0.462388  0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801
# 1      -0.082361 -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235
# 2       1.800499  0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084
# 3       1.247203  0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228
# 4       0.095921  0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# 0      -0.991390 -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993
# 1       0.489095 -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783
# 2       0.717293 -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857
# 3       0.507757 -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622
# 4       1.345852 -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -0.689256  4.626942 -0.924459  1.107641  1.991691  0.510632 -0.682920
# 284803  1.214756 -0.675143  1.164931 -0.711757 -0.025693 -1.221179 -1.545556
# 284804 -0.183699 -0.510602  1.329284  0.140716  0.313502  0.395652 -0.577252
# 284805 -1.042082  0.449624  1.962563 -0.608577  0.509928  1.113981  2.897849
# 284806 -0.188093 -0.084316  0.041333 -0.302620 -0.660377  0.167430 -0.256117
#
#              V20       V21       V22       V23       V24       V25       V26  \
# 0       0.251412 -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1      -0.069083 -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2       0.524980  0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3      -0.208038 -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4       0.408542 -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.475829  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034
# 284803  0.059616  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255
# 284804  0.001396  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371
# 284805  0.127434  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668
# 284806  0.382948  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267
#
#              V27       V28  Amount  Class
# 0       0.133558 -0.021053  149.62      0
# 1      -0.008983  0.014724    2.69      0
# 2      -0.055353 -0.059752  378.66      0
# 3       0.062723  0.061458  123.50      0
# 4       0.219422  0.215153   69.99      0
# ...          ...       ...     ...    ...
# 284802  0.943651  0.823731    0.77      0
# 284803  0.068472 -0.053527   24.79      0
# 284804  0.004455 -0.026561   67.88      0
# 284805  0.108821  0.104533   10.00      0
# 284806 -0.002415  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
#Split train and test Data

df = df.drop(['Amount', 'Time'], axis = 1)
train_data = df.sample(frac=0.8, random_state=200)
test_data = df.drop(train_data.index)
test_data_no_y = test_data.drop(columns=['Class'])
test_data_no_y.head()
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 0  -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 2  -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 9  -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
# 10  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152 -1.423236
# 13  1.069374  0.287722  0.828613  2.712520 -0.178398  0.337544 -0.096717
#
#           V8        V9       V10       V11       V12       V13       V14  \
# 0   0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 2   0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 9   0.069539 -0.736727 -0.366846  1.017614  0.836390  1.006844 -0.443523
# 10  0.048456 -1.720408  1.626659  1.199644 -0.671440 -0.513947 -0.095045
# 13  0.115982 -0.221083  0.460230 -0.773657  0.323387 -0.011076 -0.178485
#
#          V15       V16       V17       V18       V19       V20       V21  \
# 0   1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 2   2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 9   0.150219  0.739453 -0.540980  0.476677  0.451773  0.203711 -0.246914
# 10  0.230930  0.031967  0.253415  0.854344 -0.221365 -0.387226 -0.009302
# 13 -0.655564 -0.199925  0.124005 -0.980496 -0.982916 -0.153197 -0.036876
#
#          V22       V23       V24       V25       V26       V27       V28
# 0   0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 2   0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 9  -0.633753 -0.120794 -0.385050 -0.069733  0.094199  0.246219  0.083076
# 10  0.313894  0.027740  0.500512  0.251367 -0.129478  0.042850  0.016253
# 13  0.074412 -0.071407  0.104744  0.548265  0.104094  0.021491  0.021293

# %%
import sagemaker
session = sagemaker.Session()

# %%
# Upload the data to be used later

train_file = 'train_data.csv'
train_data.to_csv(train_file, index=False, header=True)
train_path = session.upload_data(path=train_file, key_prefix="cc_fraud" + "/train")
print(f"Upload file to {train_path}")
# Out:
# Upload file to s3://sagemaker-us-east-1-629589781736/cc_fraud/train/train_data.csv

# %%
# Upload test data 

test_file = 'test_data.csv'
test_data_no_y.to_csv(test_file, index=False, header=False)
test_path = session.upload_data(path=test_file, key_prefix="cc_fraud" + "/test")
print(f"Upload file to {test_path}")
# Out:
# Upload file to s3://sagemaker-us-east-1-629589781736/cc_fraud/test/test_data.csv

# %%
bucket = 'sagemaker-us-east-1-629589781736'
prefix = 'cc_fraud'

auto_ml_job_config = {
        'CompletionCriteria': {
            'MaxCandidates': 5
        }
    }
input_data_config = [{
      'DataSource': {
        'S3DataSource': {
          'S3DataType': 'S3Prefix',
          'S3Uri': 's3://{}/{}/train'.format(bucket, prefix)
        }
      },
      'TargetAttributeName': 'Class'
    }
  ]
output_data_config = {
    'S3OutputPath': 's3://{}/{}/output/'.format(bucket, prefix)
  }
from time import gmtime, strftime, sleep
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())
auto_ml_job_name = f'automl-fraudcase-{timestamp_suffix}'
print(f"AutoMLJobName:{auto_ml_job_name}")
# Out:
# AutoMLJobName:automl-fraudcase-03-00-03-23

# %%
from time import gmtime, strftime, sleep
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())

auto_ml_job_name = f'automl-fraudcase-{timestamp_suffix}'
print(f"AutoMLJobName:{auto_ml_job_name}")
# Out:
# AutoMLJobName:automl-fraudcase-03-00-14-16

# %%
from sagemaker import get_execution_role
import boto3

region ='us-east-1'

role = get_execution_role()
sm = boto3.Session().client(service_name='sagemaker',region_name=region)
sm.create_auto_ml_job(AutoMLJobName=auto_ml_job_name,
                      InputDataConfig=input_data_config,
                      OutputDataConfig=output_data_config,
                      AutoMLJobConfig=auto_ml_job_config,
                      RoleArn=role)
# Out:
# {'AutoMLJobArn': 'arn:aws:sagemaker:us-east-1:629589781736:automl-job/automl-fraudcase-03-00-14-16',
#  'ResponseMetadata': {'RequestId': '4469e8fe-6c89-45f8-9251-fecf25ad1609',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '4469e8fe-6c89-45f8-9251-fecf25ad1609',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '99',
#    'date': 'Sun, 03 Apr 2022 00:14:20 GMT'},
#   'RetryAttempts': 0}}

# %%
print('JobStatus  Secondary Status')

print('-------------------------------------')
describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
print(f"{describe_response['AutoMLJobStatus']} - {describe_response['AutoMLJobSecondaryStatus']}")

job_run_status = describe_response['AutoMLJobStatus']
      
while job_run_status not in ('Failed', 'Completed', 'Stopped'):
      
      describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
      job_run_status = describe_response['AutoMLJobStatus']

      print(f"{describe_response['AutoMLJobStatus']} - {describe_response['AutoMLJobSecondaryStatus']}")
      sleep(30)
# Out:
# JobStatus  Secondary Status
# -------------------------------------
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingExplainabilityReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# InProgress - GeneratingModelInsightsReport
# Completed - Completed

# %%
best_candidate = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['BestCandidate']
best_candidate_name = best_candidate['CandidateName']

print(best_candidate)

print('\n')
print(f"CandidateName:{best_candidate_name}")
print(f"FinalAutoMLJobObjectiveMetricName: {best_candidate['FinalAutoMLJobObjectiveMetric']['MetricName']}")
print(f"FinalAutoMLJobObjectiveMetricValue: {str(best_candidate['FinalAutoMLJobObjectiveMetric']['Value'])}")
# Out:
# {'CandidateName': 'automl-fraudcase-03-00-14-16nqgU-003-8adae4c5', 'FinalAutoMLJobObjectiveMetric': {'MetricName': 'validation:f1_binary', 'Value': 0.7173900008201599}, 'ObjectiveStatus': 'Succeeded', 'CandidateSteps': [{'CandidateStepType': 'AWS::SageMaker::ProcessingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:629589781736:processing-job/automl-fraudcase-03-00-14-16-db-1-099575e782cd49f29b226c409f7f2', 'CandidateStepName': 'automl-fraudcase-03-00-14-16-db-1-099575e782cd49f29b226c409f7f2'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:629589781736:training-job/automl-fraudcase-03-00-14-16-dpp0-1-92c8ae5f8de440ad8d24f293c93', 'CandidateStepName': 'automl-fraudcase-03-00-14-16-dpp0-1-92c8ae5f8de440ad8d24f293c93'}, {'CandidateStepType': 'AWS::SageMaker::TransformJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:629589781736:transform-job/automl-fraudcase-03-00-14-16-dpp0-csv-1-9496641db6be438fbb52891', 'CandidateStepName': 'automl-fraudcase-03-00-14-16-dpp0-csv-1-9496641db6be438fbb52891'}, {'CandidateStepType': 'AWS::SageMaker::TrainingJob', 'CandidateStepArn': 'arn:aws:sagemaker:us-east-1:629589781736:training-job/automl-fraudcase-03-00-14-16nqgu-003-8adae4c5', 'CandidateStepName': 'automl-fraudcase-03-00-14-16nqgU-003-8adae4c5'}], 'CandidateStatus': 'Completed', 'InferenceContainers': [{'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-629589781736/cc_fraud/output/automl-fraudcase-03-00-14-16/data-processor-models/automl-fraudcase-03-00-14-16-dpp0-1-92c8ae5f8de440ad8d24f293c93/output/model.tar.gz', 'Environment': {'AUTOML_TRANSFORM_MODE': 'feature-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'application/x-recordio-protobuf', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}}, {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.3-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-629589781736/cc_fraud/output/automl-fraudcase-03-00-14-16/tuning/automl-fra-dpp0-xgb/automl-fraudcase-03-00-14-16nqgU-003-8adae4c5/output/model.tar.gz', 'Environment': {'MAX_CONTENT_LENGTH': '20971520', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,probabilities'}}, {'Image': '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-sklearn-automl:2.5-1-cpu-py3', 'ModelDataUrl': 's3://sagemaker-us-east-1-629589781736/cc_fraud/output/automl-fraudcase-03-00-14-16/data-processor-models/automl-fraudcase-03-00-14-16-dpp0-1-92c8ae5f8de440ad8d24f293c93/output/model.tar.gz', 'Environment': {'AUTOML_TRANSFORM_MODE': 'inverse-label-transform', 'SAGEMAKER_DEFAULT_INVOCATIONS_ACCEPT': 'text/csv', 'SAGEMAKER_INFERENCE_INPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_OUTPUT': 'predicted_label', 'SAGEMAKER_INFERENCE_SUPPORTED': 'predicted_label,probability,labels,probabilities', 'SAGEMAKER_PROGRAM': 'sagemaker_serve', 'SAGEMAKER_SUBMIT_DIRECTORY': '/opt/ml/model/code'}}], 'CreationTime': datetime.datetime(2022, 4, 3, 0, 40, 6, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2022, 4, 3, 0, 41, 50, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2022, 4, 3, 0, 47, 57, 896000, tzinfo=tzlocal()), 'CandidateProperties': {'CandidateArtifactLocations': {'Explainability': 's3://sagemaker-us-east-1-629589781736/cc_fraud/output/automl-fraudcase-03-00-14-16/documentation/explainability/output', 'ModelInsights': 's3://sagemaker-us-east-1-629589781736/cc_fraud/output/automl-fraudcase-03-00-14-16/documentation/model_monitor/output'}, 'CandidateMetrics': [{'MetricName': 'F1', 'Value': 0.7173900008201599, 'Set': 'Validation'}, {'MetricName': 'AUC', 'Value': 0.9772199988365173, 'Set': 'Validation'}, {'MetricName': 'Accuracy', 'Value': 0.9988600015640259, 'Set': 'Validation'}]}}
#
#
# CandidateName:automl-fraudcase-03-00-14-16nqgU-003-8adae4c5
# FinalAutoMLJobObjectiveMetricName: validation:f1_binary
# FinalAutoMLJobObjectiveMetricValue: 0.7173900008201599

# %%
model_name = 'automl-fraudcase-model-' + timestamp_suffix
model = sm.create_model(Containers=best_candidate['InferenceContainers'],
                            ModelName=model_name,
                            ExecutionRoleArn=role)
print('Model ARN corresponding to the best candidate is : {}'.format(model['ModelArn']))
# Out:
# Model ARN corresponding to the best candidate is : arn:aws:sagemaker:us-east-1:629589781736:model/automl-fraudcase-model-03-00-14-16
